# %%
from bs4 import BeautifulSoup
import requests
import pandas
from openpyxl import load_workbook

# %%
wb = load_workbook(filename = './links.xlsx')
print(wb)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 wb = load_workbook(filename = './links.xlsx')
#       2 print(wb)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:315, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     288 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     289                   data_only=False, keep_links=True):
#     290     """Open the given filename and return the workbook
#     291
#     292     :param filename: the path to open or a file-like object
#    (...)
#     313
#     314     """
# --> 315     reader = ExcelReader(filename, read_only, keep_vba,
#     316                         data_only, keep_links)
#     317     reader.read()
#     318     return reader.wb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:124, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122 def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123               data_only=False, keep_links=True):
# --> 124     self.archive = _validate_archive(fn)
#     125     self.valid_files = self.archive.namelist()
#     126     self.read_only = read_only
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:96, in _validate_archive(filename)
#      89             msg = ('openpyxl does not support %s file format, '
#      90                    'please check you can open '
#      91                    'it with Excel first. '
#      92                    'Supported formats are: %s') % (file_format,
#      93                                                    ','.join(SUPPORTED_FORMATS))
#      94         raise InvalidFileException(msg)
# ---> 96 archive = ZipFile(filename, 'r')
#      97 return archive
#
# File ~\AppData\Local\Programs\Python\Python310\lib\zipfile.py:1240, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1238 while True:
#    1239     try:
# -> 1240         self.fp = io.open(file, filemode)
#    1241     except OSError:
#    1242         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: './links.xlsx'

# %%
sheet_ranges = wb['sheet1']
print(sheet_ranges)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 sheet_ranges = wb['sheet1']
#       2 print(sheet_ranges)
#
# NameError: name 'wb' is not defined

# %%
names = []
for row in sheet_ranges.iter_rows(): 
    for cell in row:
        cell.value = cell.value.replace(' ','_')
        names.append(cell.value)
print(names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       2 for row in sheet_ranges.iter_rows():
#       3     for cell in row:
# ----> 4         cell.value = cell.value.replace(' ','_')
#       5         names.append(cell.value)
#       6 print(names)
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
urls = []
for name in names:
    url = 'https://www.google.com/travel/hotels/'+name+'?'
    urls.append(url)

for index,url in enumerate(urls):
    print(index+1,url)
# Out:
# 1 https://www.google.com/travel/hotels/N_Seoul_Tower?
# 2 https://www.google.com/travel/hotels/Aldeia_Hanok_de_Bukchon?
# 3 https://www.google.com/travel/hotels/Myeong-dong?
# 4 https://www.google.com/travel/hotels/Lotte_World?
# 5 https://www.google.com/travel/hotels/창덕궁인정문?
# 6 https://www.google.com/travel/hotels/Cheonggyecheon,_Seoul?
# 7 https://www.google.com/travel/hotels/Nami_Island?
# 8 https://www.google.com/travel/hotels/DDP_동대문디자인플라자?
# 9 https://www.google.com/travel/hotels/Everland_Theme_Park?
# 56 https://www.google.com/travel/hotels/Ihwa_Mural_Village,_Seoul?
# 57 https://www.google.com/travel/hotels/Trickeye_Museum_Seoul?
# 58 https://www.google.com/travel/hotels/Andong_Hahoe_Folk_Village?
# 59 https://www.google.com/travel/hotels/Cheomseongdae?
# 60 https://www.google.com/travel/hotels/Jusangjeollidae?
# 61 https://www.google.com/travel/hotels/Gwangan_Bridge?
# 62 https://www.google.com/travel/hotels/Seoul_Grand_Park?
# 63 https://www.google.com/travel/hotels/Hallasan_National_Park?
# 64 https://www.google.com/travel/hotels/Pyeongchang_Alpensia?
# 65 https://www.google.com/travel/hotels/Cheonjiyeon_Waterfall?
# 66 https://www.google.com/travel/hotels/Hyeopjae_Beach?
# 67 https://www.google.com/travel/hotels/Jeju_Love_Land?
# 68 https://www.google.com/travel/hotels/Seoul_Land?
# 69 https://www.google.com/travel/hotels/Seoullo_7017?
# 70 https://www.google.com/travel/hotels/Gwanghwamun_Square?
# 71 https://www.google.com/travel/hotels/Caribbean_Bay?
# 72 https://www.google.com/travel/hotels/63_Building?
# 73 https://www.google.com/travel/hotels/Seoul_Children's_Grand_Park?
# 74 https://www.google.com/travel/hotels/Hamdeok_Beach?
# 75 https://www.google.com/travel/hotels/Gyeongju_National_Museum?
# 76 https://www.google.com/travel/hotels/High1_Ski_Resort?
# 77 https://www.google.com/travel/hotels/Yeouido_Park?
# 78 https://www.google.com/travel/hotels/Udo?
# 79 https://www.google.com/travel/hotels/Kukje_Gallery?
# 80 https://www.google.com/travel/hotels/SEALIFE_Busan_Aquarium?
# 81 https://www.google.com/travel/hotels/Heunginjimun?
# 82 https://www.google.com/travel/hotels/Gukje_Market?
# 83 https://www.google.com/travel/hotels/Chiri-san?
# 84 https://www.google.com/travel/hotels/Seoul_Museum_of_History?
# 85 https://www.google.com/travel/hotels/Oryukdo_Skywalk?
# 86 https://www.google.com/travel/hotels/Songdo_Central_Park?
# 87 https://www.google.com/travel/hotels/Blue_House?
# 88 https://www.google.com/travel/hotels/National_Palace_Museum_of_Korea?
# 89 https://www.google.com/travel/hotels/Coex_Aquarium?
# 90 https://www.google.com/travel/hotels/Wolmido?
# 91 https://www.google.com/travel/hotels/Namhansanseong_North_Gate?
# 92 https://www.google.com/travel/hotels/Suncheon_Bay_Nature_Reserve?
# 93 https://www.google.com/travel/hotels/Daereungwon_Tomb_Complex?
# 94 https://www.google.com/travel/hotels/Haneul_Park?
# 95 https://www.google.com/travel/hotels/Seopjikoji?
# 96 https://www.google.com/travel/hotels/Seomun_Market?
# 97 https://www.google.com/travel/hotels/Seodaemun_Prison_History_Hall?
# 98 https://www.google.com/travel/hotels/Yeouido?

# %%
def getHotels(url):
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text,'lxml')
    tab = soup.find('div',class_='l5cSPd')
    container = tab.find_all('c-wiz',class_='f1dFQe')
    name = ''
    for div in container[:3]:
        hotel = div.find('div',class_='QT7m7')
        if hotel:
            name+=hotel.text+' | '
        else:
            continue
    if len(name) > 1:
        return name
    else:
        return 'none'

# %%
for index,url in enumerate(urls):
    print(getHotels(url))
# Out:
# Pacific Hotel | K-POP HOTEL Seoul Tower | Hotel Prince Seoul |
# Insa Hostel in Seoul | Nine Tree Premier Hotel Insadong | Rakkojae Seoul Bukchon Hanok Village Main Hanok |
# Four Points by Sheraton Josun, Seoul Myeongdong | Tmark Grand Hotel, Myeongdong | LOTTE City Hotel, Myeongdong |
# LOTTE Hotel World | Signiel Seoul | Rosana Boutique Hotel |
# Todaki Guesthouse (토다기 게스트하우스) | Hanok Guesthouse 202 | Rakkojae Seoul Bukchon Hanok Village Main Hanok |
# LOTTE City Hotel, Myeongdong | KOREANA HOTEL | The Grand Hotel Myeongdong |
# Hotel Jeonggwanru | W Jiwoo Resort | White Vill Pension |
# Star Hostel Seoul Dongdeamun | Seoul Datbit DDP Guesthouse | Philstay Hostel DDP |
# Hotel Thesoom Forest | Ramada by Wyndham Yongin | Golden Tulip Ever Yongin |
# ITAEWON INN | Novotel Ambassador Seoul Yongsan | Itaewon Crown Tourist Hotel |
# K-POP HOTEL Seoul Tower | Hotel 8 hours | Tmark Grand Hotel, Myeongdong |
# Best Western Haeundae Hotel | Sunset Business Hotel | ibis Ambassador Busan Haeundae |
# Airhostel in Seoul | Star Hostel Seoul Dongdeamun | Ramada by Wyndham Seoul Dongdaemun |
# Ananti Hilton Busan | Osiria | Ananti Cove |
# Kensington Hotel Seorak | Kensington Hotel | Seorak Park Resort |
# KOREANA HOTEL | 24 Guesthouse Seoul City Hall | Hotel 8 hours |
# 365 Businesstel | Kolon Hotel | Gyeongju Bulguksa Youth Town |
# 탑클라우드호텔수원점 | Hotel Dono | 썬스타모텔 |
# none
# 남포하운드호텔프리미어 | Bangga Bangga Guesthouse | Hermes Hotel |
# Nine Tree Premier Hotel Insadong | Shilla Stay Gwanghwamun | Nine Tree Premier Hotel Insadong |
# 용인 몬터레이17 호텔 | Astro Hotel | 스카이호텔 |
# IP Boutique Hotel | G Guesthouse Itaewon | Grand Hyatt Seoul |
# 성산일출봉 펜션 | Golden Tulip Hotel Jeju Seongsan | The Best Jeju Seongsan Hotel |
# Best Western Arirang Hill Dongdaemun | 동화킴스관광호텔 | Solarium City |
# Lotte Resort Jeju Art Villas | Lotte Hotel Jeju | Donnaeko Hill Resort |
# Insa Hostel in Seoul | Rakkojae Seoul Bukchon Hanok Village Main Hanok | Somerset Palace Seoul |
# Homers Hotel | H Avenue Hotel Gwangalli branch | Hotel Gwangan Pico Blue |
# 황남관 한옥체험마을 Hwangnamguan Hanok Village & Hotel | 소풍길민박(gyeong ju guest house sopunggil) | Soi Hanok Stay |
# ITAEWON INN | Novotel Ambassador Seoul Yongsan | YaKorea Hostel Itaewon, Seoul, South Korea |
# Seoul Loft Apartments (SLA) | Orakai Daehakro Hotel | MayPlace Hotel |
# Lavalse Hotel | 태종파크텔 | G2모텔 |
# Kensington Hotel Seorak | The K Seoraksan Family Hotel | Kensington Hotel |
# Millennium Hilton Seoul | K-POP HOTEL Seoul Tower | Pacific Hotel |
# Jeonju Hanok Village accommodation yard pretty house | 전주 한옥마을 돌담집 | Yangsajae |
# Shilla Stay Gwanghwamun | Insa Hostel in Seoul | Somerset Palace Seoul |
# The Grand Hotel Myeongdong | ibis Styles Ambassador Seoul Myeongdong | Hotel Double A Myeongdong |
# 오션스카이빌리지 | 숲속에향기 | 빈티지1950펜션 |
# Hotel 8 hours | K-POP HOTEL Seoul Tower | 24 Guesthouse Seoul City Hall |
# Airhostel in Seoul | SUMMIT HOTEL SEOUL | Hotel Skypark Kingstown Dongdaemun |
# Paraspara Seoul | Solarium City | 은평한옥마을 채효당 |
# 니즈호텔 | Benikea Yangsan Hotel | 에스모텔 |
# Hotel Gracery Seoul | K-POP HOTEL Seoul Tower | Hotel 8 hours |
# Queen Elizabeth Olympic Park | Beijing Olympic Park | Olympic Park |
# Castle Lake Bed and Breakfast | Lideoseu | 정화여각 |
# Seoul Forest Stay | Chris Hostel | Hotel K World |
# Dal's Garden | 해인사관광호텔 | Pandora's box Pensions |
# Airhostel in Seoul | Naksan Balcony | 호스텔코리아 오리지널 |
# Kolon Hotel | BROWN-DOT HOTEL GYEONGJU | Arisu Gyeongju Hotel |
# Nol Guest House - Hostel | Easystay Guest House | Global Inn Busan Nampodong Hotel |
# ITAEWON INN | JW Marriott Hotel Seoul | Itaewon Crown Tourist Hotel |
# GLAD Gangnam COEX center | InterContinental Seoul Parnas | Park Hyatt Seoul |
# Lotte Hotel Jeju | You Us Hotel | Grand Josun Jeju |
# 소피텔 앰배서더 서울 호텔 & 서비스드 레지던스 | Signiel Seoul | Hotel the Castle Jamsil |
# Phoenix Pyeongchang | White Cabin | Hotel Atrium Pyeongchang |
# Airhostel in Seoul | Star Hostel Seoul Dongdeamun | Seoul N Hotel Dongdaemun |
# Marigold Hotel | Mercure Ambassador Seoul Hongdae | Holiday Inn Express Seoul Hongdae, an IHG Hotel |
# Rakkojae Andong Hahoe Folk Village 락고재 안동 하회마을 | Andong CM Park Hotel | Okyeonjeongsa |
# Mini Hotel 141 | Doran Doran Guest House | 소풍길민박(gyeong ju guest house sopunggil) |
# Lotte Hotel Jeju | The Seaes Hotel & Resort, Jeju | Jeju Booyoung Hotel & Resort |
# none
# Orakai Cheonggyesan Hotel | Hilton Garden Inn Seoul Gangnam | 센트럴관광호텔 |
# Lotte Resort Jeju Art Villas | Lotte Hotel Jeju | 제주아이브 |
# Yong Pyong Ski Resort | Yongpyong Resort Tower Condominium | InterContinental Alpensia Pyeongchang Resort |
# 호텔윈스토리 | Park sunshine jeju | Poong Gyung Hotel |
