# %%
from bs4 import BeautifulSoup
import requests

# %%
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhMKCC9tLzA2c3JrEgdTZW5lZ2FsUgRgAXgB&dest_mid=%2Fm%2F06srk&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhMKCC9tLzA2dGd3EgdTb21hbGlhUgRgAXgB&dest_mid=%2Fm%2F06tgw&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzA2dHc4EgVTdWRhblIEYAF4AQ&dest_mid=%2Fm%2F06tw8&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhIKCC9tLzA3dHAyEgZVZ2FuZGFSBGABeAE&dest_mid=%2Fm%2F07tp2&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhIKBy9tLzBoM3kSB0FsZ2VyaWFSBGABeAE&dest_mid=%2Fm%2F0h3y&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAxNjR2EgVCZW5pblIEYAF4AQ&dest_mid=%2Fm%2F0164v&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhMKCC9tLzAxNjl0EgdCdXJ1bmRpUgRgAXgB&dest_mid=%2Fm%2F0169t&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhQKCC9tLzAxbmxuEghDYW1lcm9vblIEYAF4AQ&dest_mid=%2Fm%2F01nln&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text

soup = BeautifulSoup(html_text, 'lxml')
#print(soup.prettify())

# %%
places = []
div_list = soup.find_all('div',class_='skFvHc')
for index,each_div in enumerate(div_list):
    places.append(each_div.text)
    print(each_div.text.strip())
# Out:
# Mount Cameroon
# Waza National Park
# Dja Faunal Reserve
# Chutes de la Lobé
# Korup National Park
# Parc de la Méfou
# Lobéké National Park
# Museu Etnográfico dos Povos da Floresta
# Station Coloniale Allemande
# National Museum
# Limbe Wildlife Centre
# Benoue National Park
# Campo Reserve
# Monument de la Réunification
# Hotel Lobe
# Blackitude Museum
# Doual'art
# Limbe Botanic Garden
# La Nouvelle Liberté
# Marché des Fleurs
# Chutes d'Ekom
# Ayos Centre
# Ancienne Residence du Chef de Circonscription
# Maritime Museum Of Douala
# Bouba Ndjida National Park
# Jardin zoologique de Mvog-Betsi
# Mount Manengouba
# Bandjoun Station
# CLUB MARKET VIP LOUNGE
# Gorges de Kola
# Boucareau
# Cathedral of St Peter and Paul Bonadibong
# Faro Reserve
# Chutes de la Métché
# Statue of Charles Atangana
# Mankon Museum
# Musée des civilisations de Dschang
# Kribi beach
# Nki National Park
# Mount Oku
# Eco Park
# Mount Cameroon National Park
# Lake Monoun
# Site Touristique D'EBOGO
# Douala-Edea Reserve
# Lake Oku
# Boumba Bek National Park
# Lake Barombi
# Parc Bonanjo
# Mount Mbapit
# Lac Petpenoun
# Ancien Commissariat de Police
# Lake Ossa
# Muanenguba Lakes
# Basilica of Mary Queen of Apostles
# Bakossi Mountains Wildlife Reserve
# SAVE AFRICA
# Mbam et Djerem National Park
# Paroisse Francophone Saint-Esprit de Mvolye
# FUN CENTER
# Takamanda Production Forest
# Rond-Point Deido
# Kumbo Cathedral
# Dent de Mindif
# Lac Baleng
# La Pagode
# Nsapé
# Lac Tison
# Ile Djébalé
# Monument Nachtigal
# Ngoyè
# Adamawa Plateau
# Municipal Lake
# Centre Culturel de la vallée du Logone
# Méfou
# Musée des Rois Bamoun
# Mont Nlonako
# Monastère Du Mont FEBE
# Lake Maga
# Lake Bermin
# Chefferie Bandjoun
# Banyang Mbo Protected Area
# Vallee du Mbere Protected area
# Mayo Kalliao
# Mont Eloundem
# Limbe River
# Palace of the Kings Bell
# Bottle Peak
# Mosquée centrale biyemassi
# Centre culturel et Musée de la Vallée du Logone
# ILE DE MANOKA
# Lac municipal de Dschang
# Mpem et Djim Protected area
# ALCEF PARK
# Musée Baham
# Musée De Foumban
# Lake Barombi Koto
# Lake Tissongo
# Mount Kupe

# %%
type_list = soup.find_all('div',class_="GwjAi")
for typeM in type_list:
    if typeM.find('div',class_="nFoFM").text:
        print(typeM.find('div',class_="nFoFM").text.strip())
    else:
        print('none')
# Out:
# Volcanic mountain with a yearly race
# Vast, scenic destination with wildlife
# Massive rainforest housing many primates
# Waterfall
# Rainforest park for day hikes & camping
# Park
# Forested park with gorillas & elephants
# none
# none
# Grand villa with local history exhibits
# Wildlife and gorillas
# Riverside nature & wildlife reserve
# Park, gorillas, ecotourism, protected area, and forest
# Monument and history
# none
# Museum and art
# Museum focused on local urban art
# Garden
# History
# none
# Waterfall
# Palace, architecture, and monument
# none
# Museum for local maritime heritage
# Wildlife habitat with diverse species
# Wildlife park with animals on display
# Volcano with crater lake & amphibians
# Art and museum
# none
# Nature
# Beach
# Cathedral, architecture, church, and history
# Park
# none
# none
# Museum
# Museum
# Beach
# Park, elephant, forest, protected area, and gorillas
# Mountain, volcano, and forest
# none
# none
# Lake and volcano
# none
# Park
# Lake and frogs
# Park, elephant, and forest
# Lake, forest, and volcano
# none
# Lake and volcano
# Lake
# History
# Lake, manatees, and forest
# Lake
# Basilica
# Park, forest, and nature
# Ecotourism
# Park and forest
# Church
# none
# Park and gorillas
# History
# Cathedral
# none
# Lake
# none
# none
# Lake
# none
# none
# none
# Mountain and volcano
# Lake
# Museum
# none
# none
# Mountain
# Monastery
# none
# Lake
# none
# none
# Park
# none
# Nature
# none
# Palace
# none
# none
# Museum
# none
# Lake and nature
# Park
# Amusement park
# Museum
# none
# Lake and volcano
# Lake
# Mountain

# %%
rate_span = soup.find_all('div',class_="GwjAi")
for each_rate in rate_span:
    if each_rate.find('span',class_="KFi5wf"):
        print(each_rate.find('span',class_="KFi5wf").text.strip())
    else:
        print('none')
# Out:
# 4.2
# 3.9
# 4.0
# 4.4
# none
# 4.4
# none
# 4.0
# 5.0
# 4.0
# 3.8
# none
# 3.8
# 4.0
# 4.0
# 3.9
# 4.0
# 4.0
# 4.3
# 3.3
# 4.4
# 4.1
# 5.0
# 4.0
# none
# 3.3
# 4.7
# 4.0
# 5.0
# 4.2
# 3.7
# 4.2
# none
# 4.2
# 3.6
# 4.1
# 3.9
# 4.3
# none
# 4.6
# 3.7
# 4.2
# 4.0
# 3.9
# 3.3
# 4.7
# none
# 3.5
# 3.4
# 4.4
# 4.7
# 3.0
# 3.9
# 3.6
# 4.2
# none
# none
# none
# 4.2
# 3.8
# none
# 3.7
# 4.3
# 4.4
# 4.0
# 3.1
# 2.7
# 3.8
# 4.0
# 5.0
# 4.8
# 4.2
# 3.4
# 3.8
# none
# 4.5
# 4.5
# 4.1
# 4.2
# 3.0
# 4.1
# none
# none
# 3.2
# 3.8
# 3.9
# none
# none
# 3.9
# 5.0
# 4.0
# 3.9
# none
# 4.1
# 4.7
# 4.0
# 3.0
# 4.0
# 3.6

# %%
webLinks = []
for link in places:
    link = link.replace(" ","_")
    #print(link)
    url = "https://en.wikipedia.org/wiki/"+link
    webLinks.append(url)

# %%
#webLinks[] = ''

for index,url in enumerate(webLinks):
    print(url)
# Out:
# https://en.wikipedia.org/wiki/Mount_Cameroon
# https://en.wikipedia.org/wiki/Waza_National_Park
# https://en.wikipedia.org/wiki/Dja_Faunal_Reserve
# https://en.wikipedia.org/wiki/Chutes_de_la_Lobé
# https://en.wikipedia.org/wiki/Korup_National_Park
# https://en.wikipedia.org/wiki/Parc_de_la_Méfou
# https://en.wikipedia.org/wiki/Lobéké_National_Park
# https://en.wikipedia.org/wiki/Museu_Etnográfico_dos_Povos_da_Floresta
# https://en.wikipedia.org/wiki/Station_Coloniale_Allemande
# https://en.wikipedia.org/wiki/National_Museum
# https://en.wikipedia.org/wiki/Limbe_Wildlife_Centre
# https://en.wikipedia.org/wiki/Benoue_National_Park
# https://en.wikipedia.org/wiki/Campo_Reserve
# https://en.wikipedia.org/wiki/Monument_de_la_Réunification
# https://en.wikipedia.org/wiki/Hotel_Lobe
# https://en.wikipedia.org/wiki/Blackitude_Museum
# https://en.wikipedia.org/wiki/Doual'art
# https://en.wikipedia.org/wiki/Limbe_Botanic_Garden
# https://en.wikipedia.org/wiki/La_Nouvelle_Liberté
# https://en.wikipedia.org/wiki/Marché_des_Fleurs
# https://en.wikipedia.org/wiki/Chutes_d'Ekom
# https://en.wikipedia.org/wiki/Ayos_Centre
# https://en.wikipedia.org/wiki/Ancienne_Residence_du_Chef_de_Circonscription
# https://en.wikipedia.org/wiki/Maritime_Museum_Of_Douala
# https://en.wikipedia.org/wiki/Bouba_Ndjida_National_Park
# https://en.wikipedia.org/wiki/Jardin_zoologique_de_Mvog-Betsi
# https://en.wikipedia.org/wiki/Mount_Manengouba
# https://en.wikipedia.org/wiki/Bandjoun_Station
# https://en.wikipedia.org/wiki/CLUB_MARKET_VIP_LOUNGE
# https://en.wikipedia.org/wiki/Gorges_de_Kola
# https://en.wikipedia.org/wiki/Boucareau
# https://en.wikipedia.org/wiki/Cathedral_of_St_Peter_and_Paul_Bonadibong
# https://en.wikipedia.org/wiki/Faro_Reserve
# https://en.wikipedia.org/wiki/Chutes_de_la_Métché
# https://en.wikipedia.org/wiki/Statue_of_Charles_Atangana
# https://en.wikipedia.org/wiki/Mankon_Museum
# https://en.wikipedia.org/wiki/Musée_des_civilisations_de_Dschang
# https://en.wikipedia.org/wiki/Kribi_beach
# https://en.wikipedia.org/wiki/Nki_National_Park
# https://en.wikipedia.org/wiki/Mount_Oku
# https://en.wikipedia.org/wiki/Eco_Park
# https://en.wikipedia.org/wiki/Mount_Cameroon_National_Park
# https://en.wikipedia.org/wiki/Lake_Monoun
# https://en.wikipedia.org/wiki/Site_Touristique_D'EBOGO
# https://en.wikipedia.org/wiki/Douala-Edea_Reserve
# https://en.wikipedia.org/wiki/Lake_Oku
# https://en.wikipedia.org/wiki/Boumba_Bek_National_Park
# https://en.wikipedia.org/wiki/Lake_Barombi
# https://en.wikipedia.org/wiki/Parc_Bonanjo
# https://en.wikipedia.org/wiki/Mount_Mbapit
# https://en.wikipedia.org/wiki/Lac_Petpenoun
# https://en.wikipedia.org/wiki/Ancien_Commissariat_de_Police
# https://en.wikipedia.org/wiki/Lake_Ossa
# https://en.wikipedia.org/wiki/Muanenguba_Lakes
# https://en.wikipedia.org/wiki/Basilica_of_Mary_Queen_of_Apostles
# https://en.wikipedia.org/wiki/Bakossi_Mountains_Wildlife_Reserve
# https://en.wikipedia.org/wiki/SAVE_AFRICA
# https://en.wikipedia.org/wiki/Mbam_et_Djerem_National_Park
# https://en.wikipedia.org/wiki/Paroisse_Francophone_Saint-Esprit_de_Mvolye
# https://en.wikipedia.org/wiki/FUN_CENTER
# https://en.wikipedia.org/wiki/Takamanda_Production_Forest
# https://en.wikipedia.org/wiki/Rond-Point_Deido
# https://en.wikipedia.org/wiki/Kumbo_Cathedral
# https://en.wikipedia.org/wiki/Dent_de_Mindif
# https://en.wikipedia.org/wiki/Lac_Baleng
# https://en.wikipedia.org/wiki/La_Pagode
# https://en.wikipedia.org/wiki/Nsapé
# https://en.wikipedia.org/wiki/Lac_Tison
# https://en.wikipedia.org/wiki/Ile_Djébalé
# https://en.wikipedia.org/wiki/Monument_Nachtigal
# https://en.wikipedia.org/wiki/Ngoyè
# https://en.wikipedia.org/wiki/Adamawa_Plateau
# https://en.wikipedia.org/wiki/Municipal_Lake
# https://en.wikipedia.org/wiki/Centre_Culturel_de_la_vallée_du_Logone
# https://en.wikipedia.org/wiki/Méfou
# https://en.wikipedia.org/wiki/Musée_des_Rois_Bamoun
# https://en.wikipedia.org/wiki/Mont_Nlonako
# https://en.wikipedia.org/wiki/Monastère_Du_Mont_FEBE
# https://en.wikipedia.org/wiki/Lake_Maga
# https://en.wikipedia.org/wiki/Lake_Bermin
# https://en.wikipedia.org/wiki/Chefferie_Bandjoun
# https://en.wikipedia.org/wiki/Banyang_Mbo_Protected_Area
# https://en.wikipedia.org/wiki/Vallee_du_Mbere_Protected_area
# https://en.wikipedia.org/wiki/Mayo_Kalliao
# https://en.wikipedia.org/wiki/Mont_Eloundem
# https://en.wikipedia.org/wiki/Limbe_River
# https://en.wikipedia.org/wiki/Palace_of_the_Kings_Bell
# https://en.wikipedia.org/wiki/Bottle_Peak
# https://en.wikipedia.org/wiki/Mosquée_centrale_biyemassi
# https://en.wikipedia.org/wiki/Centre_culturel_et_Musée_de_la_Vallée_du_Logone
# https://en.wikipedia.org/wiki/ILE_DE_MANOKA
# https://en.wikipedia.org/wiki/Lac_municipal_de_Dschang
# https://en.wikipedia.org/wiki/Mpem_et_Djim_Protected_area
# https://en.wikipedia.org/wiki/ALCEF_PARK
# https://en.wikipedia.org/wiki/Musée_Baham
# https://en.wikipedia.org/wiki/Musée_De_Foumban
# https://en.wikipedia.org/wiki/Lake_Barombi_Koto
# https://en.wikipedia.org/wiki/Lake_Tissongo
# https://en.wikipedia.org/wiki/Mount_Kupe

# %%
location_list = []

def getLocation(url):
    if url !='nn':
        web_text = requests.get(url).text
        web_soup = BeautifulSoup(web_text,'lxml')
        table = web_soup.find('table', class_='infobox')
        if table:
            tr_list = table.find_all('tr')
            for tr in tr_list:
                if tr.th and (tr.th.text == 'Location' or tr.th.text == 'Province' or tr.th.text == 'District' or tr.th.text == 'Town or city'):
                    if tr.td:
                        location = tr.td.text
                        location_list.append(location.strip())
                        return location
    else:
        location_list.append('none')

# %%
for index,url in enumerate(webLinks):
    print(getLocation(url))
# Out:
# Southwest Region, Cameroon
# Far North Province, Cameroon
# Cameroon
# None
# Southwest Province, Cameroon, Cameroon
# None
# Cameroon
# None
# None
# None
# None
# Cameroon
# None
# None
# None
# Yaoundé , Cameroon
# Place du GouvernementBonanjo Douala, Cameroon
# Limbe, Cameroon
# Rond-Point Deïdo Douala, Cameroon
# None
# None
# None
# None
# None
#  Cameroon
# None
# Cameroon
# None
# None
# None
# None
# None
# None
# None
# None
# Mankon-Bamenda, Cameroon
# None
# None
# Cameroon
# Northwest Region,Cameroon
# None
# Southwest Region, Cameroon
# None
# None
# None
# None
# Cameroon
# None
# None
# None
# None
# None
# Littoral Province
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Douala
# None
# None
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
#       1 for index,url in enumerate(webLinks):
# ----> 2     print(getLocation(url))
#
# Input In [45], in getLocation(url)
#       3 def getLocation(url):
#       4     if url !='nn':
# ----> 5         web_text = requests.get(url).text
#       6         web_soup = BeautifulSoup(web_text,'lxml')
#       7         table = web_soup.find('table', class_='infobox')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     498             raise
#     500 except (ProtocolError, socket.error) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
def getVisitors(url):
    if url != 'nn':
        html_text = requests.get(url).text
        soup = BeautifulSoup(html_text,'lxml')
        table = soup.find('table',class_="infobox")
        if table:
            tr_list = table.find_all('tr')
            for tr in tr_list:
                if tr.th and ('Visitors' in tr.th.text or 'Attendees' in tr.th.text or 'Attenders' in tr.th.text):
                    return tr.td.text
    return 'none'

# %%
for index,url in enumerate(webLinks):
    print(getVisitors(url))
# Out:
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# 1070 (2011)
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
