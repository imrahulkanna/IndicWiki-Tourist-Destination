# %% [markdown]
# ## Importing modules

# %%
from bs4 import BeautifulSoup
import requests
import pandas
from openpyxl import load_workbook

# %% [markdown]
# ## Getting the html text from the website

# %%
#html_text = requests.get('https://en.wikipedia.org/wiki/List_of_amusement_parks_in_the_United_Kingdom').text
#html_text = requests.get('https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Kuala_Lumpur').text
#html_text = requests.get('https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Penang').text
#html_text = requests.get('https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Singapore').text
#html_text = requests.get('https://en.wikipedia.org/wiki/List_of_museums_in_Singapore').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzXzNkEgVKYXBhblIEYAF4AQ&dest_mid=%2Fm%2F03_3d&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhwKBy9tLzBqancSD0FydCBhbmQgY3VsdHVyZSgB').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzXzNkEgVKYXBhblIEYAF4AQ&dest_mid=%2Fm%2F03_3d&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=Eh4KCS9tLzAxMGpqchIPQW11c2VtZW50IHBhcmtzKAE').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzXzNkEgVKYXBhblIEYAF4AQ&dest_mid=%2Fm%2F03_3d&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhQKCC9tLzA3MWswEgZTa2lpbmcoAQ').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhQKCS9tLzAxY3JkNRIHVmlldG5hbVIEYAF4AQ&dest_mid=%2Fm%2F01crd5&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhQKCC9tLzA3ZjF4EghUaGFpbGFuZFIEYAF4AQ&dest_mid=%2Fm%2F07f1x&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhUKCC9tLzBiM3lyEgdCZWFjaGVzKAE').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhQKCC9tLzA3ZjF4EghUaGFpbGFuZFIEYAF4AQ&dest_mid=%2Fm%2F07f1x&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhUKCC9tLzA5Y21xEgdNdXNldW1zKAE').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhQKCC9tLzA3ZjF4EghUaGFpbGFuZFIEYAF4AQ&dest_mid=%2Fm%2F07f1x&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=Eh8KDS9nLzExYzcxaHZmdDASDEtpZCBmcmllbmRseSgB').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhUKCC9tLzAzcnluEglJbmRvbmVzaWFSBGABeAE&dest_mid=%2Fm%2F03ryn&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzcmswEgVJbmRpYVIEYAF4AQ&dest_mid=%2Fm%2F03rk0&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhwKBy9tLzBqancSD0FydCBhbmQgY3VsdHVyZSgB').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzcmswEgVJbmRpYVIEYAF4AQ&dest_mid=%2Fm%2F03rk0&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzcmswEgVJbmRpYVIEYAF4AQ&dest_mid=%2Fm%2F03rk0&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhEKCC9tLzAzcmswEgVJbmRpYVIEYAF4AQ&dest_mid=%2Fm%2F03rk0&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhkKCS9tLzAxejIxNRIMU2F1ZGkgQXJhYmlhUgRgAXgB&dest_mid=%2Fm%2F01z215&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhkKCS9tLzAxejIxNRIMU2F1ZGkgQXJhYmlhUgRgAXgB&dest_mid=%2Fm%2F01z215&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhsKDS9nLzExYmM1OGwxM3cSCE91dGRvb3JzKAE').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EiAKCC9tLzBqMXo4EhRVbml0ZWQgQXJhYiBFbWlyYXRlc1IEYAF4AQ&dest_mid=%2Fm%2F0j1z8&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd&rf=EhwKBy9tLzBqancSD0FydCBhbmQgY3VsdHVyZSgB').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=
ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhcKCC9tLzAybHgwEgtUaW1vci1MZXN0ZVIEYAF4AQ&dest_mid=%2Fm%2F02lx0&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhMKCC9tLzAxNjViEgdCZXJtdWRhUgRgAXgB&dest_mid=%2Fm%2F0165b&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhcKCC9tLzA1cjd0EgtQdWVydG8gUmljb1IEYAF4AQ&dest_mid=%2Fm%2F05r7t&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EicKCC9tLzBjdnZjEhtBbmRhbWFuIGFuZCBOaWNvYmFyIElzbGFuZHNSBGABeAE&dest_mid=%2Fm%2F0cvvc&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
# html_text = requests.get('https://www.google.com/travel/things-to-do/see-all?dest_src=ut&tcfs=EhkKCS9tLzAxMWh2bhIMU2FpbnQgTWFydGluUgRgAXgB&dest_mid=%2Fm%2F011hvn&ved=0CAUQyJABahgKEwjYo6eBmer2AhUAAAAAHQAAAAAQ2QE&ictx=3&gsas=1&dest_state_type=sattd').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text
#html_text = requests.get('').text

soup = BeautifulSoup(html_text, 'lxml')
#print(soup.prettify())

# %% [markdown]
# # For Wiki links

# %% [markdown]
# ## Extracting tourist places

# %%
# ul_list = soup.find_all('ul')
# for each_ul  in ul_list[1:17]:
#     for li in each_ul:
#         place = li.text.replace(" ",'')
#         #print(li.text.strip())

# %% [markdown]
# ## Extracting wiki urls for the places

# %%
# webLinks = []
# for ul in ul_list[1:17]:
#     li_list = ul.find_all('li')
#     for li in li_list:
#         a = li.find('a')  # find_all() will give a list iterate and find() gives the tag from which we can get the attributes
#         url = 'https://en.wikipedia.org'+str(a["href"])
#         webLinks.append(url)

# %% [markdown]
# ## Extracting Location of the tourist places from Wiki

# %%
# location_list = []
# def getLocation(url):
#     web_text = requests.get(url).text
#     web_soup = BeautifulSoup(web_text,'lxml')
#     table = web_soup.find('table', class_='infobox')
#     if table:
#         tr_list = table.find_all('tr')
#         for tr in tr_list:
#             if tr.th and tr.th.text == 'Location':
#                 location = tr.td.text
#                 location_list.append(location)
#                 return location

# %%
# for index,url in enumerate(webLinks):
#     print(getLocation(url))

# %%
# ul_list = soup.find_all('ul')
# c=0
# for each_ul in ul_list[1:2]:
# #     print(each_ul.prettify())
#     for li in each_ul:
#         place = li.text.replace(" ",'')
#         print(li.text.strip())
#         c+=1
# print(c)

# %% [markdown]
# ## Extracting wiki links

# %%
# webLinks = []
# for ul in ul_list[1:2]:
#     li_list = ul.find_all('li')
#     for li in li_list:
#         if li.find('a'):
#             a = li.find('a')  # find_all() will give a list iterate and find() gives the tag from which we can get the attributes
#             if a['href']:
#                 url = 'https://en.wikipedia.org'+str(a["href"])
#                 webLinks.append(url)
#                 print(url)
#             else:
#                 webLinks.append('none')
#                 print('none')
        
# print(len(webLinks))

# %% [markdown]
# ## Getting Locations

# %%
# location_list = []
# def getLocation(url):
#     if url != 'none':
#         web_text = requests.get(url).text
#         web_soup = BeautifulSoup(web_text,'lxml')
#         table = web_soup.find('table', class_='infobox')
#         if table:
#             tr_list = table.find_all('tr')
#             for tr in tr_list:
#                 if tr.th and tr.th.text == 'Location':
#                     if tr.td:
#                         location = tr.td.text
#                         location_list.append(location.strip())
#                         return location
#     else:
#         location_list.append('none')

# %%
# for index,url in enumerate(webLinks):
#     print(getLocation(url))

# %%
# print(len(location_list))

# %% [markdown]
# ## Getting Type

# %%
# def getType(url):
#     if url!='none':
#         html_text = requests.get(url).text
#         soup = BeautifulSoup(html_text,'lxml')
#         table = soup.find('table',class_="infobox")
#         if table:
#             tr_list = table.find_all('tr')
#             for tr in tr_list:
#                 if tr.th and tr.th.text == 'Type':
#                     return tr.td.text
#     return 'none'

# %%
# for index,url in enumerate(webLinks):
#     print(getType(url))

# %% [markdown]
# ## Getting Visitors

# %%
# def getVisitors(url):
#     if url != 'none':
#         html_text = requests.get(url).text
#         soup = BeautifulSoup(html_text,'lxml')
#         table = soup.find('table',class_="infobox")
#         if table:
#             tr_list = table.find_all('tr')
#             for tr in tr_list:
#                 if tr.th and 'Visitors' in tr.th.text:
#                     return tr.td.text
#     return 'none'

# %%
# for index,url in enumerate(webLinks):
#     print(getVisitors(url))

# %% [markdown]
# # GOOGLE TRAVELS

# %% [markdown]
# ## Getting links from google travel

# %%
places = []
div_list = soup.find_all('div',class_='skFvHc')
for index,each_div in enumerate(div_list):
    places.append(each_div.text)
    print(each_div.text.strip())
# Out:
# Shwedagon Pagoda
# Inle Lake
# Ngapali Beach
# Kyaik Htee Yoe Pagoda
# Ananda Temple
# U Bein Bridge
# Shwezigon Pagoda
# Sule Pagoda
# Dhammayangyi Temple
# Mount Popa
# Bogyoke Aung San Market
# Mandalay Hill
# Kuthodaw Pagoda
# Shwenandaw Monastery
# Shwesandaw Pagoda
# Thatbyinnyu Phaya
# Mahamuni Buddha Temple
# Chaukhtatgyi Buddha Temple
# Mandalay Palace
# Sulamani Temple
# Kandawgyi Lake
# Htilominlo Pahto
# Botataung Pagoda
# Hsinbyume Pagoda (Myatheindan Pagoda)
# National Museum
# Gawdawpalin Temple
# Shwemawdaw Pagoda
# မွေတော်ကက္ကူ စေတီတော်
# မင်းကွန်းပုထိုးတော်ကြီး
# Laykyun Sekkya
# Sandamuni Pagoda
# Chaung Thar Beach
# Pindaya Caves
# Bu Phaya
# Shwe Inn Dein Pagoda
# Inya Lake
# National Kandawgyi Gardens
# Nga Phe Chaung Monastery
# Manuha Temple
# Kyauktawgyi Pagoda
# Kaba Aye Pagoda
# Mingun Bell
# Goteik viaduct
# Kyaik Pun Pagoda
# Phawngpui
# Shwegu Gyi Phaya
# Mount Victoria
# Uppatasanti Pagoda
# Maha Bandula Park
# Mount Zwegabin
# Bogyoke Aung San Museum
# ...

# %%
type_list = soup.find_all('div',class_="GwjAi")
for typeM in type_list:
    if typeM.find('div',class_="nFoFM").text:
        print(typeM.find('div',class_="nFoFM").text.strip())
    else:
        print('none')
# Out:
# Large gilded stupa with a visitor center
# Phaung Daw Oo & Shwe Inn Dein pagodas
# Sandy beach with swimming & fishing
# Buddhist temple on top of a boulder
# Grand 12th-century Buddhist temple
# Wooden footbridge built in the 1850s
# Landmark temple with a gilded stupa
# Golden Buddhist pagoda with statues
# Massive 12th-century Buddhist temple
# Volcano with a famed monastery
# Bustling marketplace for food & gifts
# Landmark hill with pagodas & monasteries
# Important Buddhist pilgrimage site
# Palace rooms turned Buddhist monastery
# Historic site with panoramic viewpoints
# Imposing Buddhist temple, 60 m. tall
# Sacred site with a large, bronze Buddha
# Iconic spot with a huge reclining Buddha
# Palace with towers, mausoleums & more
# Ancient Buddhist temple with relics
# Reservoir & park with pagoda views
# Red-brick Buddhist temple built in 1211
# Monumental pagoda with a Buddha relic
# Striking 19th-century white pagoda
# Burmese culture & history museum
# ...

# %%
rate_span = soup.find_all('div',class_="GwjAi")
for each_rate in rate_span:
    if each_rate.find('span',class_="KFi5wf"):
        print(each_rate.find('span',class_="KFi5wf").text.strip())
    else:
        print('none')
# Out:
# 4.8
# 4.6
# 4.6
# 4.6
# 4.7
# none
# 4.6
# 4.3
# 4.6
# 4.2
# 4.1
# 4.4
# 4.5
# 4.5
# 4.5
# 4.6
# 4.6
# 4.5
# none
# 4.6
# 4.2
# 4.6
# 4.5
# 4.6
# 4.2
# 4.5
# 4.5
# 4.5
# 4.5
# none
# 4.5
# 4.3
# 4.5
# 4.4
# 4.6
# 4.3
# 4.3
# 4.3
# 4.5
# 4.5
# 4.5
# 4.3
# 4.3
# 4.3
# 3.9
# 4.4
# 4.4
# 4.5
# 4.2
# 4.7
# 4.3
# 3.9
# 4.2
# 4.4
# 4.6
# 4.3
# 4.6
# 4.6
# 4.1
# 4.6
# 4.1
# 4.3
# 4.1
# 4.6
# 4.1
# 4.5
# 4.2
# 4.5
# 4.5
# 4.4
# 4.6
# 4.4
# 4.5
# none
# 4.5
# 3.7
# 4.3
# 4.2
# 4.4
# 4.1
# 4.4
# 4.4
# 4.5
# 4.2
# 4.4
# 4.1
# 4.6
# 4.3
# 4.2
# 4.5
# 4.5
# 4.5
# 4.0
# 4.5
# 3.9
# 4.6
# 4.2
# 4.3
# 4.4

# %%
webLinks = []
for link in places:
    link = link.replace(" ","_")
    #print(link)
    url = "https://en.wikipedia.org/wiki/"+link
    webLinks.append(url)

# %%
#webLinks[] = ''

for index,url in enumerate(webLinks):
    print(url)
# Out:
# https://en.wikipedia.org/wiki/Shwedagon_Pagoda
# https://en.wikipedia.org/wiki/Inle_Lake
# https://en.wikipedia.org/wiki/Ngapali_Beach
# https://en.wikipedia.org/wiki/Kyaik_Htee_Yoe_Pagoda
# https://en.wikipedia.org/wiki/Ananda_Temple
# https://en.wikipedia.org/wiki/U_Bein_Bridge
# https://en.wikipedia.org/wiki/Shwezigon_Pagoda
# https://en.wikipedia.org/wiki/Sule_Pagoda
# https://en.wikipedia.org/wiki/Dhammayangyi_Temple
# https://en.wikipedia.org/wiki/Mount_Popa
# https://en.wikipedia.org/wiki/Bogyoke_Aung_San_Market
# https://en.wikipedia.org/wiki/Mandalay_Hill
# https://en.wikipedia.org/wiki/Kuthodaw_Pagoda
# https://en.wikipedia.org/wiki/Shwenandaw_Monastery
# https://en.wikipedia.org/wiki/Shwesandaw_Pagoda
# https://en.wikipedia.org/wiki/Thatbyinnyu_Phaya
# https://en.wikipedia.org/wiki/Mahamuni_Buddha_Temple
# https://en.wikipedia.org/wiki/Chaukhtatgyi_Buddha_Temple
# https://en.wikipedia.org/wiki/Mandalay_Palace
# https://en.wikipedia.org/wiki/Sulamani_Temple
# ...

# %%
location_list = []

def getLocation(url):
    if url !='nn':
        web_text = requests.get(url).text
        web_soup = BeautifulSoup(web_text,'lxml')
        table = web_soup.find('table', class_='infobox')
        if table:
            tr_list = table.find_all('tr')
            for tr in tr_list:
                if tr.th and (tr.th.text == 'Location' or tr.th.text == 'Province' or tr.th.text == 'District' or tr.th.text == 'Town or city'):
                    if tr.td:
                        location = tr.td.text
                        location_list.append(location.strip())
                        return location
    else:
        location_list.append('none')

# %%
for index,url in enumerate(webLinks):
    print(getLocation(url))
# Out:
# None
# Shan State
# None
# None
# Bagan, Myanmar
# None
# Nyaung-U, Myanmar
# Yangon, Burma
# None
# None
# Pabedan, Yangon, Myanmar
# Mandalay Region, Myanmar
# Mandalay
# None
# None
# None
# None
# Bahan Township, Yangon, Yangon Region
# Mandalay
# None
# Yangon
# None
# Yangon
# None
# None
# Bagan, Mandalay Region
# None
# None
# None
# Khatakan Taung, near Monywa, Myanmar
# None
# None
# Pindaya, Shan State, Burma
# None
# None
# Yangon
# None
# None
# Myinkaba, Mandalay Region
# None
# Yangon
# Mingun, Sagaing Region
# None
# None
# None
# None
# None
# Naypyidaw
# Yangon
# Kayin State, Myanmar
# 15 Bogyoke Aung San Lane, Bahan, Yangon, Myanmar16°48′13.82″N 96°9′48.20″E﻿ / ﻿16.8038389°N 96.1633889°E﻿ / 16.8038389; 96.1633889Coordinates: 16°48′13.82″N 96°9′48.20″E﻿ / ﻿16.8038389°N 96.1633889°E﻿ / 16.8038389; 96.1633889
# 40 Kaba Aye Pagoda Road Yangon Yangon Division, Myanmar
# Myanmar–Thailand border
# None
# None
# Inwa
# None
# None
# None
# None
# None
# Bago
# None
# None
# ...

# %%
def getVisitors(url):
    if url != 'nn':
        html_text = requests.get(url).text
        soup = BeautifulSoup(html_text,'lxml')
        table = soup.find('table',class_="infobox")
        if table:
            tr_list = table.find_all('tr')
            for tr in tr_list:
                if tr.th and ('Visitors' in tr.th.text or 'Attendees' in tr.th.text or 'Attenders' in tr.th.text):
                    return tr.td.text
    return 'none'

# %%
for index,url in enumerate(webLinks):
    print(getVisitors(url))
# Out:
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none
# none

# %%
# li = []
# # i = input()
# # while(i != 'break'):
# for j in range(100):
#     i = input()    
#     li.append(i)

# %%
# webLinks = li

# for index,link in enumerate(webLinks):
#     print(link)

# %%
# def getType(url):
#     if url!='none':
#         html_text = requests.get(url).text
#         soup = BeautifulSoup(html_text,'lxml')
#         table = soup.find('table',class_="infobox")
#         if table:
#             tr_list = table.find_all('tr')
#             for tr in tr_list:
#                 if tr.th and tr.th.text == 'Type':
#                     return tr.td.text
#     return 'none'

# %%
# for index,url in enumerate(webLinks):
#     print(getType(url))
